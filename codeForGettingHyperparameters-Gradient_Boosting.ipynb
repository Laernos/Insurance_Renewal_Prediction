# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats import randint, uniform
import joblib

# Load and prepare data

def load_and_prepare_data(filepath, delimiter=';', reference_date="2018-12-31"):
    df = pd.read_csv(filepath, delimiter=delimiter)

    # Convert date columns
    date_cols = ['Date_start_contract', 'Date_last_renewal', 'Date_next_renewal', 
                 'Date_birth', 'Date_driving_licence', 'Date_lapse']
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], errors='coerce', dayfirst=True)

    # Create target
    df['Renewed'] = df['Lapse'].apply(lambda x: 1 if x == 0 else 0)

    # Feature engineering
    reference_date = pd.to_datetime(reference_date)
    df['Customer_age'] = (reference_date - df['Date_birth']).dt.days // 365
    df['Driving_experience'] = (reference_date - df['Date_driving_licence']).dt.days // 365
    df['Contract_duration'] = (df['Date_next_renewal'] - df['Date_start_contract']).dt.days
    df['Experience_ratio'] = df['Driving_experience'] / (df['Customer_age'] + 1)

    # Filter outliers
    df = df[(df['Customer_age'] >= 18) & (df['Customer_age'] <= 100)]
    df = df[(df['Driving_experience'] >= 0) & (df['Driving_experience'] <= 80)]

    # Drop unused columns
    df = df.drop(columns=['ID', 'Date_start_contract', 'Date_last_renewal', 'Date_next_renewal', 
                          'Date_birth', 'Date_driving_licence', 'Date_lapse', 'Lapse'])

    # Define features and target
    X = df.drop(columns=['Renewed'])
    y = df['Renewed']

    return X, y

def create_preprocessor(X):
    categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
    numerical_cols = X.select_dtypes(include=['float64', 'int64']).columns.tolist()

    # Ensure all categoricals are strings
    for col in categorical_cols:
        X[col] = X[col].astype(str)

    numeric_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    categorical_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])

    preprocessor = ColumnTransformer([
        ('num', numeric_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

    return preprocessor

# Load data
X, y = load_and_prepare_data("Motor_vehicle_insurance_data.csv")
preprocessor = create_preprocessor(X)

# Stratified split
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in sss.split(X, y):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Build base pipeline
base_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', GradientBoostingClassifier(random_state=42))
])

# Define hyperparameter distributions
param_dist = {
    'classifier__n_estimators': randint(200, 600),
    'classifier__learning_rate': uniform(0.01, 0.09),
    'classifier__max_depth': randint(3, 10),
    'classifier__min_samples_split': randint(100, 500),
    'classifier__min_samples_leaf': randint(20, 100),
    'classifier__subsample': uniform(0.7, 0.3)
}

# Randomized Search
random_search = RandomizedSearchCV(
    base_pipeline,
    param_distributions=param_dist,
    n_iter=50,  # Number of random settings to try
    scoring='roc_auc',  # Maximize ROC-AUC
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=-1  # Use all CPUs
)

# Run tuning
print("Starting hyperparameter search...")
random_search.fit(X_train, y_train)
print("Hyperparameter search complete!")

best_model = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)

y_pred = best_model.predict(X_test)
y_pred_proba = best_model.predict_proba(X_test)[:, 1]

print("\nModel Evaluation")
print("-----------------------------")
print("Accuracy:", best_model.score(X_test, y_test))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred_proba))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

joblib.dump(best_model, "gradient_boosting_best_model.pkl")
print("\nBest Gradient Boosting model saved to '../models/gradient_boosting_best_model.pkl'")
# Out:
# /var/folders/0x/y70f9b115h59p57bg5dtc2500000gn/T/ipykernel_72279/639009843.py:17: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=delimiter)
# 🔍 Starting hyperparameter search...
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END classifier__learning_rate=0.043708610696262626, classifier__max_depth=7, classifier__min_samples_leaf=34, classifier__min_samples_split=206, classifier__n_estimators=271, classifier__subsample=0.8795975452591109; total time= 1.5min
# [CV] END classifier__learning_rate=0.043708610696262626, classifier__max_depth=7, classifier__min_samples_leaf=34, classifier__min_samples_split=206, classifier__n_estimators=271, classifier__subsample=0.8795975452591109; total time= 1.5min
# [CV] END classifier__learning_rate=0.043708610696262626, classifier__max_depth=7, classifier__min_samples_leaf=34, classifier__min_samples_split=206, classifier__n_estimators=271, classifier__subsample=0.8795975452591109; total time= 1.5min
# [CV] END classifier__learning_rate=0.024041677639819285, classifier__max_depth=5, classifier__min_samples_leaf=94, classifier__min_samples_split=187, classifier__n_estimators=572, classifier__subsample=0.8803345035229626; total time= 2.3min
# [CV] END classifier__learning_rate=0.024041677639819285, classifier__max_depth=5, classifier__min_samples_leaf=94, classifier__min_samples_split=187, classifier__n_estimators=572, classifier__subsample=0.8803345035229626; total time= 2.3min
# [CV] END classifier__learning_rate=0.024041677639819285, classifier__max_depth=5, classifier__min_samples_leaf=94, classifier__min_samples_split=187, classifier__n_estimators=572, classifier__subsample=0.8803345035229626; total time= 2.3min
# [CV] END classifier__learning_rate=0.029110519961044856, classifier__max_depth=6, classifier__min_samples_leaf=40, classifier__min_samples_split=260, classifier__n_estimators=513, classifier__subsample=0.8574269294896713; total time= 2.4min
# [CV] END classifier__learning_rate=0.04887505167779042, classifier__max_depth=3, classifier__min_samples_leaf=78, classifier__min_samples_split=269, classifier__n_estimators=387, classifier__subsample=0.8099085529881075; total time=  54.1s
# [CV] END classifier__learning_rate=0.04887505167779042, classifier__max_depth=3, classifier__min_samples_leaf=78, classifier__min_samples_split=269, classifier__n_estimators=387, classifier__subsample=0.8099085529881075; total time=  53.6s
# [CV] END classifier__learning_rate=0.04887505167779042, classifier__max_depth=3, classifier__min_samples_leaf=78, classifier__min_samples_split=269, classifier__n_estimators=387, classifier__subsample=0.8099085529881075; total time=  53.4s
# [CV] END classifier__learning_rate=0.07372653200164409, classifier__max_depth=8, classifier__min_samples_leaf=72, classifier__min_samples_split=357, classifier__n_estimators=543, classifier__subsample=0.9497327922401264; total time= 3.6min
# [CV] END classifier__learning_rate=0.07372653200164409, classifier__max_depth=8, classifier__min_samples_leaf=72, classifier__min_samples_split=357, classifier__n_estimators=543, classifier__subsample=0.9497327922401264; total time= 3.6min
# [CV] END classifier__learning_rate=0.07372653200164409, classifier__max_depth=8, classifier__min_samples_leaf=72, classifier__min_samples_split=357, classifier__n_estimators=543, classifier__subsample=0.9497327922401264; total time= 3.6min
# [CV] END classifier__learning_rate=0.029110519961044856, classifier__max_depth=6, classifier__min_samples_leaf=40, classifier__min_samples_split=260, classifier__n_estimators=513, classifier__subsample=0.8574269294896713; total time= 2.4min
# [CV] END classifier__learning_rate=0.029110519961044856, classifier__max_depth=6, classifier__min_samples_leaf=40, classifier__min_samples_split=260, classifier__n_estimators=513, classifier__subsample=0.8574269294896713; total time= 2.4min
# [CV] END classifier__learning_rate=0.06331731119758383, classifier__max_depth=5, classifier__min_samples_leaf=70, classifier__min_samples_split=234, classifier__n_estimators=220, classifier__subsample=0.8351497755908628; total time=  51.4s
# [CV] END classifier__learning_rate=0.06331731119758383, classifier__max_depth=5, classifier__min_samples_leaf=70, classifier__min_samples_split=234, classifier__n_estimators=220, classifier__subsample=0.8351497755908628; total time=  53.0s
# [CV] END classifier__learning_rate=0.06331731119758383, classifier__max_depth=5, classifier__min_samples_leaf=70, classifier__min_samples_split=234, classifier__n_estimators=220, classifier__subsample=0.8351497755908628; total time=  52.5s
# [CV] END classifier__learning_rate=0.011193846504387988, classifier__max_depth=3, classifier__min_samples_leaf=79, classifier__min_samples_split=113, classifier__n_estimators=441, classifier__subsample=0.8156249507619748; total time= 1.1min
# [CV] END classifier__learning_rate=0.011193846504387988, classifier__max_depth=3, classifier__min_samples_leaf=79, classifier__min_samples_split=113, classifier__n_estimators=441, classifier__subsample=0.8156249507619748; total time= 1.1min
# [CV] END classifier__learning_rate=0.011436962699819277, classifier__max_depth=4, classifier__min_samples_leaf=79, classifier__min_samples_split=363, classifier__n_estimators=234, classifier__subsample=0.9727961206236346; total time=  52.1s
# [CV] END classifier__learning_rate=0.011436962699819277, classifier__max_depth=4, classifier__min_samples_leaf=79, classifier__min_samples_split=363, classifier__n_estimators=234, classifier__subsample=0.9727961206236346; total time=  52.4s
# [CV] END classifier__learning_rate=0.011193846504387988, classifier__max_depth=3, classifier__min_samples_leaf=79, classifier__min_samples_split=113, classifier__n_estimators=441, classifier__subsample=0.8156249507619748; total time= 1.1min
# [CV] END classifier__learning_rate=0.011436962699819277, classifier__max_depth=4, classifier__min_samples_leaf=79, classifier__min_samples_split=363, classifier__n_estimators=234, classifier__subsample=0.9727961206236346; total time=  52.9s
# [CV] END classifier__learning_rate=0.03329019834400152, classifier__max_depth=6, classifier__min_samples_leaf=21, classifier__min_samples_split=489, classifier__n_estimators=253, classifier__subsample=0.8640130838029838; total time= 1.2min
# [CV] END classifier__learning_rate=0.03329019834400152, classifier__max_depth=6, classifier__min_samples_leaf=21, classifier__min_samples_split=489, classifier__n_estimators=253, classifier__subsample=0.8640130838029838; total time= 1.2min
# [CV] END classifier__learning_rate=0.03329019834400152, classifier__max_depth=6, classifier__min_samples_leaf=21, classifier__min_samples_split=489, classifier__n_estimators=253, classifier__subsample=0.8640130838029838; total time= 1.2min
# [CV] END classifier__learning_rate=0.05104629857953323, classifier__max_depth=9, classifier__min_samples_leaf=81, classifier__min_samples_split=150, classifier__n_estimators=563, classifier__subsample=0.8542703315240834; total time= 3.8min
# [CV] END classifier__learning_rate=0.05104629857953323, classifier__max_depth=9, classifier__min_samples_leaf=81, classifier__min_samples_split=150, classifier__n_estimators=563, classifier__subsample=0.8542703315240834; total time= 3.8min
# [CV] END classifier__learning_rate=0.05104629857953323, classifier__max_depth=9, classifier__min_samples_leaf=81, classifier__min_samples_split=150, classifier__n_estimators=563, classifier__subsample=0.8542703315240834; total time= 3.8min
# [CV] END classifier__learning_rate=0.02663690099729743, classifier__max_depth=9, classifier__min_samples_leaf=37, classifier__min_samples_split=317, classifier__n_estimators=243, classifier__subsample=0.9818496824692566; total time= 1.8min
# [CV] END classifier__learning_rate=0.02663690099729743, classifier__max_depth=9, classifier__min_samples_leaf=37, classifier__min_samples_split=317, classifier__n_estimators=243, classifier__subsample=0.9818496824692566; total time= 1.8min
# [CV] END classifier__learning_rate=0.02663690099729743, classifier__max_depth=9, classifier__min_samples_leaf=37, classifier__min_samples_split=317, classifier__n_estimators=243, classifier__subsample=0.9818496824692566; total time= 1.8min
# [CV] END classifier__learning_rate=0.06280760490974634, classifier__max_depth=3, classifier__min_samples_leaf=79, classifier__min_samples_split=479, classifier__n_estimators=240, classifier__subsample=0.7888820517112247; total time=  31.5s
# [CV] END classifier__learning_rate=0.06280760490974634, classifier__max_depth=3, classifier__min_samples_leaf=79, classifier__min_samples_split=479, classifier__n_estimators=240, classifier__subsample=0.7888820517112247; total time=  31.3s
# [CV] END classifier__learning_rate=0.06280760490974634, classifier__max_depth=3, classifier__min_samples_leaf=79, classifier__min_samples_split=479, classifier__n_estimators=240, classifier__subsample=0.7888820517112247; total time=  31.4s
# [CV] END classifier__learning_rate=0.09053446153848839, classifier__max_depth=8, classifier__min_samples_leaf=67, classifier__min_samples_split=370, classifier__n_estimators=414, classifier__subsample=0.856250278007747; total time= 2.5min
# [CV] END classifier__learning_rate=0.024874024515670223, classifier__max_depth=3, classifier__min_samples_leaf=90, classifier__min_samples_split=108, classifier__n_estimators=543, classifier__subsample=0.8184644554526709; total time= 1.2min
# [CV] END classifier__learning_rate=0.024874024515670223, classifier__max_depth=3, classifier__min_samples_leaf=90, classifier__min_samples_split=108, classifier__n_estimators=543, classifier__subsample=0.8184644554526709; total time= 1.3min
# [CV] END classifier__learning_rate=0.09053446153848839, classifier__max_depth=8, classifier__min_samples_leaf=67, classifier__min_samples_split=370, classifier__n_estimators=414, classifier__subsample=0.856250278007747; total time= 2.5min
# [CV] END classifier__learning_rate=0.09053446153848839, classifier__max_depth=8, classifier__min_samples_leaf=67, classifier__min_samples_split=370, classifier__n_estimators=414, classifier__subsample=0.856250278007747; total time= 2.5min
# [CV] END classifier__learning_rate=0.024874024515670223, classifier__max_depth=3, classifier__min_samples_leaf=90, classifier__min_samples_split=108, classifier__n_estimators=543, classifier__subsample=0.8184644554526709; total time= 1.2min
# [CV] END classifier__learning_rate=0.09650548219144141, classifier__max_depth=7, classifier__min_samples_leaf=99, classifier__min_samples_split=336, classifier__n_estimators=537, classifier__subsample=0.8619076397167239; total time= 2.8min
# [CV] END classifier__learning_rate=0.09650548219144141, classifier__max_depth=7, classifier__min_samples_leaf=99, classifier__min_samples_split=336, classifier__n_estimators=537, classifier__subsample=0.8619076397167239; total time= 2.8min
# [CV] END classifier__learning_rate=0.09650548219144141, classifier__max_depth=7, classifier__min_samples_leaf=99, classifier__min_samples_split=336, classifier__n_estimators=537, classifier__subsample=0.8619076397167239; total time= 2.8min
# [CV] END classifier__learning_rate=0.050450560672438305, classifier__max_depth=3, classifier__min_samples_leaf=67, classifier__min_samples_split=161, classifier__n_estimators=415, classifier__subsample=0.8997767069852489; total time= 1.0min
# [CV] END classifier__learning_rate=0.050450560672438305, classifier__max_depth=3, classifier__min_samples_leaf=67, classifier__min_samples_split=161, classifier__n_estimators=415, classifier__subsample=0.8997767069852489; total time= 1.0min
# [CV] END classifier__learning_rate=0.050450560672438305, classifier__max_depth=3, classifier__min_samples_leaf=67, classifier__min_samples_split=161, classifier__n_estimators=415, classifier__subsample=0.8997767069852489; total time= 1.0min
# [CV] END classifier__learning_rate=0.0794143312017351, classifier__max_depth=7, classifier__min_samples_leaf=60, classifier__min_samples_split=127, classifier__n_estimators=334, classifier__subsample=0.9550115733369398; total time= 1.9min
# [CV] END classifier__learning_rate=0.0794143312017351, classifier__max_depth=7, classifier__min_samples_leaf=60, classifier__min_samples_split=127, classifier__n_estimators=334, classifier__subsample=0.9550115733369398; total time= 2.0min
# [CV] END classifier__learning_rate=0.0794143312017351, classifier__max_depth=7, classifier__min_samples_leaf=60, classifier__min_samples_split=127, classifier__n_estimators=334, classifier__subsample=0.9550115733369398; total time= 2.0min
# [CV] END classifier__learning_rate=0.06321680089369544, classifier__max_depth=8, classifier__min_samples_leaf=54, classifier__min_samples_split=326, classifier__n_estimators=300, classifier__subsample=0.9915136286167311; total time= 2.1min
# [CV] END classifier__learning_rate=0.048478691652269465, classifier__max_depth=4, classifier__min_samples_leaf=96, classifier__min_samples_split=278, classifier__n_estimators=262, classifier__subsample=0.9687290787020557; total time=  56.9s
# [CV] END classifier__learning_rate=0.06321680089369544, classifier__max_depth=8, classifier__min_samples_leaf=54, classifier__min_samples_split=326, classifier__n_estimators=300, classifier__subsample=0.9915136286167311; total time= 2.1min
# [CV] END classifier__learning_rate=0.03641393572462343, classifier__max_depth=9, classifier__min_samples_leaf=30, classifier__min_samples_split=180, classifier__n_estimators=591, classifier__subsample=0.9187021504122961; total time= 4.3min
# [CV] END classifier__learning_rate=0.03641393572462343, classifier__max_depth=9, classifier__min_samples_leaf=30, classifier__min_samples_split=180, classifier__n_estimators=591, classifier__subsample=0.9187021504122961; total time= 4.3min
# [CV] END classifier__learning_rate=0.06321680089369544, classifier__max_depth=8, classifier__min_samples_leaf=54, classifier__min_samples_split=326, classifier__n_estimators=300, classifier__subsample=0.9915136286167311; total time= 2.2min
# [CV] END classifier__learning_rate=0.048478691652269465, classifier__max_depth=4, classifier__min_samples_leaf=96, classifier__min_samples_split=278, classifier__n_estimators=262, classifier__subsample=0.9687290787020557; total time=  59.4s
# [CV] END classifier__learning_rate=0.048478691652269465, classifier__max_depth=4, classifier__min_samples_leaf=96, classifier__min_samples_split=278, classifier__n_estimators=262, classifier__subsample=0.9687290787020557; total time= 1.0min
# [CV] END classifier__learning_rate=0.03641393572462343, classifier__max_depth=9, classifier__min_samples_leaf=30, classifier__min_samples_split=180, classifier__n_estimators=591, classifier__subsample=0.9187021504122961; total time= 4.4min
# [CV] END classifier__learning_rate=0.08640224418394754, classifier__max_depth=7, classifier__min_samples_leaf=33, classifier__min_samples_split=458, classifier__n_estimators=482, classifier__subsample=0.8568198488145982; total time= 2.7min
# [CV] END classifier__learning_rate=0.08640224418394754, classifier__max_depth=7, classifier__min_samples_leaf=33, classifier__min_samples_split=458, classifier__n_estimators=482, classifier__subsample=0.8568198488145982; total time= 2.7min
# [CV] END classifier__learning_rate=0.08640224418394754, classifier__max_depth=7, classifier__min_samples_leaf=33, classifier__min_samples_split=458, classifier__n_estimators=482, classifier__subsample=0.8568198488145982; total time= 2.7min
# [CV] END classifier__learning_rate=0.024509915852860397, classifier__max_depth=4, classifier__min_samples_leaf=61, classifier__min_samples_split=144, classifier__n_estimators=261, classifier__subsample=0.890021126953127; total time=  49.0s
# [CV] END classifier__learning_rate=0.024509915852860397, classifier__max_depth=4, classifier__min_samples_leaf=61, classifier__min_samples_split=144, classifier__n_estimators=261, classifier__subsample=0.890021126953127; total time=  48.0s
# [CV] END classifier__learning_rate=0.024509915852860397, classifier__max_depth=4, classifier__min_samples_leaf=61, classifier__min_samples_split=144, classifier__n_estimators=261, classifier__subsample=0.890021126953127; total time=  48.2s
# [CV] END classifier__learning_rate=0.052783320086390056, classifier__max_depth=7, classifier__min_samples_leaf=23, classifier__min_samples_split=321, classifier__n_estimators=430, classifier__subsample=0.8231148769106889; total time= 2.3min
# [CV] END classifier__learning_rate=0.052783320086390056, classifier__max_depth=7, classifier__min_samples_leaf=23, classifier__min_samples_split=321, classifier__n_estimators=430, classifier__subsample=0.8231148769106889; total time= 2.2min
# [CV] END classifier__learning_rate=0.052783320086390056, classifier__max_depth=7, classifier__min_samples_leaf=23, classifier__min_samples_split=321, classifier__n_estimators=430, classifier__subsample=0.8231148769106889; total time= 2.2min
# [CV] END classifier__learning_rate=0.07799960246887437, classifier__max_depth=6, classifier__min_samples_leaf=32, classifier__min_samples_split=259, classifier__n_estimators=526, classifier__subsample=0.7869254358741303; total time= 2.2min
# [CV] END classifier__learning_rate=0.07799960246887437, classifier__max_depth=6, classifier__min_samples_leaf=32, classifier__min_samples_split=259, classifier__n_estimators=526, classifier__subsample=0.7869254358741303; total time= 2.2min
# [CV] END classifier__learning_rate=0.07799960246887437, classifier__max_depth=6, classifier__min_samples_leaf=32, classifier__min_samples_split=259, classifier__n_estimators=526, classifier__subsample=0.7869254358741303; total time= 2.2min
# [CV] END classifier__learning_rate=0.08843145311689458, classifier__max_depth=6, classifier__min_samples_leaf=63, classifier__min_samples_split=439, classifier__n_estimators=485, classifier__subsample=0.9649840776756604; total time= 2.4min
# [CV] END classifier__learning_rate=0.05596725723198091, classifier__max_depth=3, classifier__min_samples_leaf=81, classifier__min_samples_split=264, classifier__n_estimators=424, classifier__subsample=0.7359596102001048; total time=  51.0s
# [CV] END classifier__learning_rate=0.08843145311689458, classifier__max_depth=6, classifier__min_samples_leaf=63, classifier__min_samples_split=439, classifier__n_estimators=485, classifier__subsample=0.9649840776756604; total time= 2.4min
# [CV] END classifier__learning_rate=0.04843970097636307, classifier__max_depth=6, classifier__min_samples_leaf=96, classifier__min_samples_split=332, classifier__n_estimators=458, classifier__subsample=0.7020856391593572; total time= 1.7min
# [CV] END classifier__learning_rate=0.04843970097636307, classifier__max_depth=6, classifier__min_samples_leaf=96, classifier__min_samples_split=332, classifier__n_estimators=458, classifier__subsample=0.7020856391593572; total time= 1.7min
# [CV] END classifier__learning_rate=0.08843145311689458, classifier__max_depth=6, classifier__min_samples_leaf=63, classifier__min_samples_split=439, classifier__n_estimators=485, classifier__subsample=0.9649840776756604; total time= 2.4min
# [CV] END classifier__learning_rate=0.05596725723198091, classifier__max_depth=3, classifier__min_samples_leaf=81, classifier__min_samples_split=264, classifier__n_estimators=424, classifier__subsample=0.7359596102001048; total time=  51.0s
# [CV] END classifier__learning_rate=0.04843970097636307, classifier__max_depth=6, classifier__min_samples_leaf=96, classifier__min_samples_split=332, classifier__n_estimators=458, classifier__subsample=0.7020856391593572; total time= 1.7min
# [CV] END classifier__learning_rate=0.05596725723198091, classifier__max_depth=3, classifier__min_samples_leaf=81, classifier__min_samples_split=264, classifier__n_estimators=424, classifier__subsample=0.7359596102001048; total time=  50.2s
# [CV] END classifier__learning_rate=0.03919105189047466, classifier__max_depth=9, classifier__min_samples_leaf=81, classifier__min_samples_split=324, classifier__n_estimators=584, classifier__subsample=0.7683805487625824; total time= 3.4min
# [CV] END classifier__learning_rate=0.073271706300566, classifier__max_depth=3, classifier__min_samples_leaf=81, classifier__min_samples_split=151, classifier__n_estimators=467, classifier__subsample=0.7755346887476092; total time=  58.8s
# [CV] END classifier__learning_rate=0.073271706300566, classifier__max_depth=3, classifier__min_samples_leaf=81, classifier__min_samples_split=151, classifier__n_estimators=467, classifier__subsample=0.7755346887476092; total time=  57.3s
# [CV] END classifier__learning_rate=0.073271706300566, classifier__max_depth=3, classifier__min_samples_leaf=81, classifier__min_samples_split=151, classifier__n_estimators=467, classifier__subsample=0.7755346887476092; total time=  57.6s
# [CV] END classifier__learning_rate=0.05475236553031469, classifier__max_depth=3, classifier__min_samples_leaf=75, classifier__min_samples_split=180, classifier__n_estimators=386, classifier__subsample=0.882869300193969; total time=  53.4s
# [CV] END classifier__learning_rate=0.03919105189047466, classifier__max_depth=9, classifier__min_samples_leaf=81, classifier__min_samples_split=324, classifier__n_estimators=584, classifier__subsample=0.7683805487625824; total time= 3.3min
# [CV] END classifier__learning_rate=0.03919105189047466, classifier__max_depth=9, classifier__min_samples_leaf=81, classifier__min_samples_split=324, classifier__n_estimators=584, classifier__subsample=0.7683805487625824; total time= 3.3min
# [CV] END classifier__learning_rate=0.05475236553031469, classifier__max_depth=3, classifier__min_samples_leaf=75, classifier__min_samples_split=180, classifier__n_estimators=386, classifier__subsample=0.882869300193969; total time=  52.9s
# [CV] END classifier__learning_rate=0.05475236553031469, classifier__max_depth=3, classifier__min_samples_leaf=75, classifier__min_samples_split=180, classifier__n_estimators=386, classifier__subsample=0.882869300193969; total time=  53.2s
# [CV] END classifier__learning_rate=0.040385365426326515, classifier__max_depth=9, classifier__min_samples_leaf=78, classifier__min_samples_split=473, classifier__n_estimators=359, classifier__subsample=0.8556371865230098; total time= 2.2min
# [CV] END classifier__learning_rate=0.040385365426326515, classifier__max_depth=9, classifier__min_samples_leaf=78, classifier__min_samples_split=473, classifier__n_estimators=359, classifier__subsample=0.8556371865230098; total time= 2.2min
# [CV] END classifier__learning_rate=0.040385365426326515, classifier__max_depth=9, classifier__min_samples_leaf=78, classifier__min_samples_split=473, classifier__n_estimators=359, classifier__subsample=0.8556371865230098; total time= 2.2min
# [CV] END classifier__learning_rate=0.05524111209059753, classifier__max_depth=8, classifier__min_samples_leaf=20, classifier__min_samples_split=225, classifier__n_estimators=329, classifier__subsample=0.8592803749951409; total time= 1.9min
# [CV] END classifier__learning_rate=0.05524111209059753, classifier__max_depth=8, classifier__min_samples_leaf=20, classifier__min_samples_split=225, classifier__n_estimators=329, classifier__subsample=0.8592803749951409; total time= 1.9min
# [CV] END classifier__learning_rate=0.05524111209059753, classifier__max_depth=8, classifier__min_samples_leaf=20, classifier__min_samples_split=225, classifier__n_estimators=329, classifier__subsample=0.8592803749951409; total time= 1.9min
# [CV] END classifier__learning_rate=0.0432689010455264, classifier__max_depth=3, classifier__min_samples_leaf=57, classifier__min_samples_split=379, classifier__n_estimators=524, classifier__subsample=0.8896917491780738; total time= 1.2min
# [CV] END classifier__learning_rate=0.0432689010455264, classifier__max_depth=3, classifier__min_samples_leaf=57, classifier__min_samples_split=379, classifier__n_estimators=524, classifier__subsample=0.8896917491780738; total time= 1.2min
# [CV] END classifier__learning_rate=0.0432689010455264, classifier__max_depth=3, classifier__min_samples_leaf=57, classifier__min_samples_split=379, classifier__n_estimators=524, classifier__subsample=0.8896917491780738; total time= 1.2min
# [CV] END classifier__learning_rate=0.06701767396848052, classifier__max_depth=5, classifier__min_samples_leaf=35, classifier__min_samples_split=196, classifier__n_estimators=400, classifier__subsample=0.7962340194915207; total time= 1.4min
# [CV] END classifier__learning_rate=0.05030048481157825, classifier__max_depth=8, classifier__min_samples_leaf=51, classifier__min_samples_split=346, classifier__n_estimators=523, classifier__subsample=0.7242559978998145; total time= 2.5min
# [CV] END classifier__learning_rate=0.05030048481157825, classifier__max_depth=8, classifier__min_samples_leaf=51, classifier__min_samples_split=346, classifier__n_estimators=523, classifier__subsample=0.7242559978998145; total time= 2.5min
# [CV] END classifier__learning_rate=0.05030048481157825, classifier__max_depth=8, classifier__min_samples_leaf=51, classifier__min_samples_split=346, classifier__n_estimators=523, classifier__subsample=0.7242559978998145; total time= 2.5min
# [CV] END classifier__learning_rate=0.06701767396848052, classifier__max_depth=5, classifier__min_samples_leaf=35, classifier__min_samples_split=196, classifier__n_estimators=400, classifier__subsample=0.7962340194915207; total time= 1.4min
# [CV] END classifier__learning_rate=0.06701767396848052, classifier__max_depth=5, classifier__min_samples_leaf=35, classifier__min_samples_split=196, classifier__n_estimators=400, classifier__subsample=0.7962340194915207; total time= 1.4min
# [CV] END classifier__learning_rate=0.011492904603507053, classifier__max_depth=5, classifier__min_samples_leaf=38, classifier__min_samples_split=247, classifier__n_estimators=551, classifier__subsample=0.7288529653274262; total time= 1.8min
# [CV] END classifier__learning_rate=0.011492904603507053, classifier__max_depth=5, classifier__min_samples_leaf=38, classifier__min_samples_split=247, classifier__n_estimators=551, classifier__subsample=0.7288529653274262; total time= 1.8min
# [CV] END classifier__learning_rate=0.02678666593598688, classifier__max_depth=7, classifier__min_samples_leaf=22, classifier__min_samples_split=247, classifier__n_estimators=451, classifier__subsample=0.9032693085526846; total time= 2.4min
# [CV] END classifier__learning_rate=0.011492904603507053, classifier__max_depth=5, classifier__min_samples_leaf=38, classifier__min_samples_split=247, classifier__n_estimators=551, classifier__subsample=0.7288529653274262; total time= 1.8min
# [CV] END classifier__learning_rate=0.02678666593598688, classifier__max_depth=7, classifier__min_samples_leaf=22, classifier__min_samples_split=247, classifier__n_estimators=451, classifier__subsample=0.9032693085526846; total time= 2.5min
# [CV] END classifier__learning_rate=0.02678666593598688, classifier__max_depth=7, classifier__min_samples_leaf=22, classifier__min_samples_split=247, classifier__n_estimators=451, classifier__subsample=0.9032693085526846; total time= 2.5min
# [CV] END classifier__learning_rate=0.09464709380406434, classifier__max_depth=9, classifier__min_samples_leaf=20, classifier__min_samples_split=366, classifier__n_estimators=350, classifier__subsample=0.8624343921482697; total time= 2.4min
# [CV] END classifier__learning_rate=0.0726205959410574, classifier__max_depth=9, classifier__min_samples_leaf=35, classifier__min_samples_split=445, classifier__n_estimators=311, classifier__subsample=0.8665602434798386; total time= 2.1min
# [CV] END classifier__learning_rate=0.09464709380406434, classifier__max_depth=9, classifier__min_samples_leaf=20, classifier__min_samples_split=366, classifier__n_estimators=350, classifier__subsample=0.8624343921482697; total time= 2.4min
# [CV] END classifier__learning_rate=0.09464709380406434, classifier__max_depth=9, classifier__min_samples_leaf=20, classifier__min_samples_split=366, classifier__n_estimators=350, classifier__subsample=0.8624343921482697; total time= 2.5min
# [CV] END classifier__learning_rate=0.09103762514469974, classifier__max_depth=5, classifier__min_samples_leaf=28, classifier__min_samples_split=332, classifier__n_estimators=298, classifier__subsample=0.9101073489918313; total time= 1.3min
# [CV] END classifier__learning_rate=0.057668552052040585, classifier__max_depth=4, classifier__min_samples_leaf=20, classifier__min_samples_split=403, classifier__n_estimators=453, classifier__subsample=0.969164727385998; total time= 1.7min
# [CV] END classifier__learning_rate=0.0726205959410574, classifier__max_depth=9, classifier__min_samples_leaf=35, classifier__min_samples_split=445, classifier__n_estimators=311, classifier__subsample=0.8665602434798386; total time= 2.2min
# [CV] END classifier__learning_rate=0.057668552052040585, classifier__max_depth=4, classifier__min_samples_leaf=20, classifier__min_samples_split=403, classifier__n_estimators=453, classifier__subsample=0.969164727385998; total time= 1.7min
# [CV] END classifier__learning_rate=0.057668552052040585, classifier__max_depth=4, classifier__min_samples_leaf=20, classifier__min_samples_split=403, classifier__n_estimators=453, classifier__subsample=0.969164727385998; total time= 1.7min
# [CV] END classifier__learning_rate=0.09103762514469974, classifier__max_depth=5, classifier__min_samples_leaf=28, classifier__min_samples_split=332, classifier__n_estimators=298, classifier__subsample=0.9101073489918313; total time= 1.3min
# [CV] END classifier__learning_rate=0.0726205959410574, classifier__max_depth=9, classifier__min_samples_leaf=35, classifier__min_samples_split=445, classifier__n_estimators=311, classifier__subsample=0.8665602434798386; total time= 2.2min
# [CV] END classifier__learning_rate=0.09103762514469974, classifier__max_depth=5, classifier__min_samples_leaf=28, classifier__min_samples_split=332, classifier__n_estimators=298, classifier__subsample=0.9101073489918313; total time= 1.3min
# [CV] END classifier__learning_rate=0.08619950280144753, classifier__max_depth=6, classifier__min_samples_leaf=43, classifier__min_samples_split=153, classifier__n_estimators=319, classifier__subsample=0.9663310296282879; total time= 1.7min
# [CV] END classifier__learning_rate=0.08619950280144753, classifier__max_depth=6, classifier__min_samples_leaf=43, classifier__min_samples_split=153, classifier__n_estimators=319, classifier__subsample=0.9663310296282879; total time= 1.7min
# [CV] END classifier__learning_rate=0.08658356038907614, classifier__max_depth=3, classifier__min_samples_leaf=91, classifier__min_samples_split=203, classifier__n_estimators=539, classifier__subsample=0.8742059864309364; total time= 1.4min
# [CV] END classifier__learning_rate=0.08658356038907614, classifier__max_depth=3, classifier__min_samples_leaf=91, classifier__min_samples_split=203, classifier__n_estimators=539, classifier__subsample=0.8742059864309364; total time= 1.4min
# [CV] END classifier__learning_rate=0.08658356038907614, classifier__max_depth=3, classifier__min_samples_leaf=91, classifier__min_samples_split=203, classifier__n_estimators=539, classifier__subsample=0.8742059864309364; total time= 1.4min
# [CV] END classifier__learning_rate=0.04350544899055688, classifier__max_depth=3, classifier__min_samples_leaf=44, classifier__min_samples_split=448, classifier__n_estimators=583, classifier__subsample=0.791609158103318; total time= 1.4min
# [CV] END classifier__learning_rate=0.08619950280144753, classifier__max_depth=6, classifier__min_samples_leaf=43, classifier__min_samples_split=153, classifier__n_estimators=319, classifier__subsample=0.9663310296282879; total time= 1.7min
# [CV] END classifier__learning_rate=0.04350544899055688, classifier__max_depth=3, classifier__min_samples_leaf=44, classifier__min_samples_split=448, classifier__n_estimators=583, classifier__subsample=0.791609158103318; total time= 1.4min
# [CV] END classifier__learning_rate=0.04350544899055688, classifier__max_depth=3, classifier__min_samples_leaf=44, classifier__min_samples_split=448, classifier__n_estimators=583, classifier__subsample=0.791609158103318; total time= 1.3min
# [CV] END classifier__learning_rate=0.0537052378227604, classifier__max_depth=5, classifier__min_samples_leaf=99, classifier__min_samples_split=268, classifier__n_estimators=360, classifier__subsample=0.7054226090846563; total time= 1.1min
# [CV] END classifier__learning_rate=0.0537052378227604, classifier__max_depth=5, classifier__min_samples_leaf=99, classifier__min_samples_split=268, classifier__n_estimators=360, classifier__subsample=0.7054226090846563; total time= 1.1min
# [CV] END classifier__learning_rate=0.0537052378227604, classifier__max_depth=5, classifier__min_samples_leaf=99, classifier__min_samples_split=268, classifier__n_estimators=360, classifier__subsample=0.7054226090846563; total time= 1.1min
# [CV] END classifier__learning_rate=0.054450434366509114, classifier__max_depth=6, classifier__min_samples_leaf=27, classifier__min_samples_split=234, classifier__n_estimators=394, classifier__subsample=0.8972838676901029; total time= 1.8min
# [CV] END classifier__learning_rate=0.054450434366509114, classifier__max_depth=6, classifier__min_samples_leaf=27, classifier__min_samples_split=234, classifier__n_estimators=394, classifier__subsample=0.8972838676901029; total time= 1.8min
# [CV] END classifier__learning_rate=0.054450434366509114, classifier__max_depth=6, classifier__min_samples_leaf=27, classifier__min_samples_split=234, classifier__n_estimators=394, classifier__subsample=0.8972838676901029; total time= 1.8min
# [CV] END classifier__learning_rate=0.04150705669252081, classifier__max_depth=3, classifier__min_samples_leaf=47, classifier__min_samples_split=466, classifier__n_estimators=516, classifier__subsample=0.8497580139654256; total time= 1.2min
# [CV] END classifier__learning_rate=0.06114777430019244, classifier__max_depth=6, classifier__min_samples_leaf=78, classifier__min_samples_split=470, classifier__n_estimators=574, classifier__subsample=0.7751385455816752; total time= 2.3min
# [CV] END classifier__learning_rate=0.06114777430019244, classifier__max_depth=6, classifier__min_samples_leaf=78, classifier__min_samples_split=470, classifier__n_estimators=574, classifier__subsample=0.7751385455816752; total time= 2.3min
# [CV] END classifier__learning_rate=0.06114777430019244, classifier__max_depth=6, classifier__min_samples_leaf=78, classifier__min_samples_split=470, classifier__n_estimators=574, classifier__subsample=0.7751385455816752; total time= 2.3min
# [CV] END classifier__learning_rate=0.06148037792882648, classifier__max_depth=3, classifier__min_samples_leaf=36, classifier__min_samples_split=271, classifier__n_estimators=419, classifier__subsample=0.8409833541972829; total time=  57.7s
# [CV] END classifier__learning_rate=0.06308837628044894, classifier__max_depth=8, classifier__min_samples_leaf=70, classifier__min_samples_split=363, classifier__n_estimators=482, classifier__subsample=0.8303183096531286; total time= 2.6min
# [CV] END classifier__learning_rate=0.04150705669252081, classifier__max_depth=3, classifier__min_samples_leaf=47, classifier__min_samples_split=466, classifier__n_estimators=516, classifier__subsample=0.8497580139654256; total time= 1.2min
# [CV] END classifier__learning_rate=0.04150705669252081, classifier__max_depth=3, classifier__min_samples_leaf=47, classifier__min_samples_split=466, classifier__n_estimators=516, classifier__subsample=0.8497580139654256; total time= 1.1min
# [CV] END classifier__learning_rate=0.06308837628044894, classifier__max_depth=8, classifier__min_samples_leaf=70, classifier__min_samples_split=363, classifier__n_estimators=482, classifier__subsample=0.8303183096531286; total time= 2.6min
# [CV] END classifier__learning_rate=0.06148037792882648, classifier__max_depth=3, classifier__min_samples_leaf=36, classifier__min_samples_split=271, classifier__n_estimators=419, classifier__subsample=0.8409833541972829; total time=  51.4s
# [CV] END classifier__learning_rate=0.06148037792882648, classifier__max_depth=3, classifier__min_samples_leaf=36, classifier__min_samples_split=271, classifier__n_estimators=419, classifier__subsample=0.8409833541972829; total time=  48.2s
# [CV] END classifier__learning_rate=0.06308837628044894, classifier__max_depth=8, classifier__min_samples_leaf=70, classifier__min_samples_split=363, classifier__n_estimators=482, classifier__subsample=0.8303183096531286; total time= 2.4min
# ✅ Hyperparameter search complete!
# 🏆 Best Parameters: {'classifier__learning_rate': 0.03641393572462343, 'classifier__max_depth': 9, 'classifier__min_samples_leaf': 30, 'classifier__min_samples_split': 180, 'classifier__n_estimators': 591, 'classifier__subsample': 0.9187021504122961}
#
# ✅ Model Evaluation
# -----------------------------
# Accuracy: 0.8768888257306617
# ROC AUC Score: 0.8950125261851196
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.50      0.62      4310
#            1       0.88      0.97      0.93     16801
#
#     accuracy                           0.88     21111
#    macro avg       0.86      0.74      0.78     21111
# weighted avg       0.87      0.88      0.86     21111
#
#
# ✅ Best Gradient Boosting model saved to '../models/gradient_boosting_best_model.pkl'
